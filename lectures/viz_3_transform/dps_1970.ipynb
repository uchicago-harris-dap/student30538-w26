# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from altair) (4.25.1)
# Collecting narwhals>=1.27.1 (from altair)
#   Downloading narwhals-2.15.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from altair) (25.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from altair) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/ml_env/lib/python3.12/site-packages (from jinja2->altair) (3.0.3)
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 761.1 kB/s  0:00:01eta 0:00:01
# Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
# Installing collected packages: narwhals, altair
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [altair]s]
# Successfully installed altair-6.0.0 narwhals-2.15.0

# %%
import pandas as pd
import altair as alt    
movies_url = 'https://cdn.jsdelivr.net/npm/vega-datasets@1/data/movies.json'
movies = pd.read_json(movies_url)

# scatter plot, filtered to < 1970
# alt.Chart(movies_url).mark_circle().encode(
#     alt.X('Rotten_Tomatoes_Rating:Q', title = "Rotten Tomatoes Rating (%)"),
#     alt.Y('IMDB_Rating:Q', title = "IMDB Rating")
# ).transform_filter('year(datum.Release_Date) < 1970'
# ).properties(title = "Pre-1970 Sample")

alt.Chart(movies_url).mark_bar().transform_filter(
    'datum.Director != null'
).transform_aggregate(
    Gross='average(Worldwide_Gross)',
    groupby=['Director']
).transform_window(
    Rank='rank()',
    sort=[alt.SortField('Gross',order="descending")]
).transform_filter(
    'datum.Rank<10'
).encode(
    alt.X('Gross:Q',title="Average worldwide gross per year"),
    alt.Y('Director:N',sort=alt.EncodingSortField(
        op='max',field='Gross',order='descending'),
        title="Director"))
# Out:
# alt.Chart(...)
